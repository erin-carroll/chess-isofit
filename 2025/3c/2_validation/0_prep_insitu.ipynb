# %%
import sys
sys.path.append('/home/carroll/Documents/')

import numpy as np
import os
import pandas as pd
from glob import glob

import matplotlib.pyplot as plt
import scipy.io as scio
from scipy.signal import savgol_filter
import asdprocessor
import asd_jump_correction

# %matplotlib widget

# %%
# prep in situ validation targets

os.chdir('/store/carroll/col/data/2025/')

wl_neon = np.loadtxt('/store/carroll/col/data/wavelengths_neon.txt')[:,1]*1000 # nm
wl_asd = np.loadtxt('/store/carroll/col/data/wavelengths_asd.txt')

# %%
dat = pd.read_csv('target_rfl_20250723.csv')
dat
# Out:
#                   file_tag      date          site     350.0     351.0  \
# 0         20250621_airpark  20250621       airpark  0.057646  0.057665
# 1         20250621_airpark  20250621       airpark  0.057470  0.057412
# 2         20250621_airpark  20250621       airpark  0.049818  0.049456
# 3         20250621_airpark  20250621       airpark  0.048911  0.048652
# 4         20250621_airpark  20250621       airpark  0.052677  0.052666
# ..                     ...       ...           ...       ...       ...
# 425  20250714_savoy_gravel  20250714  savoy_gravel  0.062805  0.062932
# 426  20250714_savoy_gravel  20250714  savoy_gravel  0.055387  0.055518
# 427  20250714_savoy_gravel  20250714  savoy_gravel  0.054201  0.054216
# 428  20250714_savoy_gravel  20250714  savoy_gravel  0.054911  0.055223
# 429  20250714_savoy_gravel  20250714  savoy_gravel  0.051528  0.051649
#
#         352.0     353.0     354.0     355.0     356.0  ...    2491.0  \
# ...

# %%
list(dat.file_tag.unique())
# Out:
# ['20250621_airpark',
#  '20250621_baseballdirt',
#  '20250621_busstop',
#  '20250621_grassflat',
#  '20250621_low_talus_slope',
#  '20250621_matterhorn_lot',
#  '20250621_mtcb_gravel_flat',
#  '20250621_rainbow_park_grass',
#  '20250621_sand',
#  '20250626_airpark',
#  '20250626_bus_stop',
#  '20250626_dirt',
#  '20250626_grass',
#  '20250626_gravel_lot',
#  '20250626_sand',
#  '20250626_veg_slope_1',
#  '20250709_EL_val1',
#  '20250709_EL_val2',
#  '20250709_cp_matterhornlot',
#  '20250709_matterhornlot',
#  '20250710_busstop_cp',
#  '20250710_busstop_prx',
#  '20250714_carbon_creek_red',
#  '20250714_carboncreek_se122',
#  '20250714_savoy_gravel']

# %%
rfl =

# %%
import os
from glob import glob

# %%
fids = glob('/store/carroll/col/data/2018/raw/rmbl/*/*.hdr')
fids = list(set([x.split('/')[-1].split('_rdn')[0] for x in fids]))
len(fids), fids[0]
# Out:
# (102, 'NIS01_20180621_180118')

# %%
fp_out = '/store/carroll/repos/neon-isofit/deploy/crbu_2018_fids.txt'
with open(fp_out, 'w') as f:
    f.write('\n'.join(fids))

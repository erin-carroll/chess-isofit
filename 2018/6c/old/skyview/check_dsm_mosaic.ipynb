# %%
import os
from matplotlib import pyplot as plt

from spectral.io import envi

# %%
fp = '/store/carroll/col/data/2018/skyview/dsm_10m_mosaic_bbox_buf1250m.hdr'
dsm = envi.open(fp).open_memmap()[...,0]

fig = plt.figure()

plt.imshow(dsm)
plt.colorbar()

plt.show()

# %%
# now visualize the skyview factor for 10m

fp = '/store/carroll/col/data/2018/skyview/sky_view_factor.hdr'
skyview = envi.open(fp).open_memmap()[...,0]

fig = plt.figure()

plt.imshow(skyview)
plt.colorbar()

plt.show()

# %%
# 1m dem

fp = '/store/carroll/col/data/2018/skyview/dsm_1m_mosaic_bbox_buf1250m.hdr'
dsm = envi.open(fp).open_memmap()[...,0]

fig = plt.figure()

plt.imshow(dsm)
plt.colorbar()

plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %matplotlib widget

# %%
home = '/store/carroll/col/data/2018/'

# %%
surface_mat =  loadmat(os.path.join(home, 'test_roi/surface_20240103_avirii_20250730.mat'))
wl = surface_mat['wl']
covs = surface_mat['covs']
means = surface_mat['means']

# %%
# not sure what the attributes are, but everything else makes sense
surface_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'normalize', 'wl', 'means', 'covs', 'attribute_means', 'attribute_covs', 'attributes', 'refwl'])

# %%
# are there 6 groups because that's how they clustered, or because there are 6 components identified in the surface model json?

fig, axs = plt.subplots(nrows=2, ncols=6, figsize=(30,10))

for i in range(covs.shape[0]):
    axs[0,i].plot(wl[0,], means[i])
    axs[1,i].imshow(covs[i,...])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# first looking at what happens if I make them all super weak
